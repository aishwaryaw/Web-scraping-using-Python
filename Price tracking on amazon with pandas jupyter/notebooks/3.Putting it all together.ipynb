# %%
import os
from requests_html import HTML
import requests
import time
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import datetime

# %%
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome(options= options) # so that browser does not get open everytime we run the code.

# %%
BASE_DIR = Path.cwd()
data_dir = os.path.join(BASE_DIR , "data")
os.makedirs(data_dir, exist_ok = True)
product_category_links_output = os.path.join(data_dir , "category-products.csv")
products_output = os.path.join(data_dir , "products.csv")

# %%
categories = [
    {"url" : "https://www.amazon.com/Best-Sellers-Toys-Games/zgbs/toys-and-games/", "category_name":"toys-and-games"},
    {"url" : "https://www.amazon.in/gp/bestsellers/electronics/ref=zg_bs_nav_0","category_name":"electronics"},
    {"url":"https://www.amazon.in/gp/bestsellers/garden/ref=zg_bs_nav_0", "category_name":"garden"}
]

# %%
# 1
def scrape_category_product_links(categories = []): 
    all_product_links = []
    for category in categories:
        url = category['url']
#         category_name = category['category_name']
        driver.get(url)
        body_el = driver.find_element_by_css_selector("body")
        html_str = body_el.get_attribute("innerHTML")
        html_obj = HTML(html = html_str)
        page_links = [f"https://www.amazon.com{x}" for x in html_obj.links if x.startswith("/")]
        cleaned_page_links = clean_page_links(page_links, category=category)
        all_product_links += cleaned_page_links
    return all_product_links

# %%
# 5
def scrape_product_page(url, title_lookup="#productTitle", price_lookup="#priceblock_ourprice"):
    driver.get(url)
#     print(url)
    time.sleep(2)
    body_el = driver.find_element_by_css_selector("body")
    html_str = body_el.get_attribute("innerHTML")
    html_obj = HTML(html = html_str)
    title = html_obj.find(title_lookup, first=True).text # first= True as find returns a list of elements
#     print(html_obj.find(title_lookup, first=True))
    price = html_obj.find(price_lookup, first=True).text
    return title, price

# scrape_product_page("https://www.amazon.com/Munchkin-17040-Fishin-Bath-Toy/dp/B01N52DUNK/ref=zg_bs_toys-and-games_32?_encoding=UTF8&psc=1&refRID=6GGEZWST2GSQY9R15K77")
# Out:
# ("Munchkin Fishin' Bath Toy", '$7.73')

# %%
regex_options = [
    r"https://www.amazon.com/(?P<slug>[\w-]+)/dp/(?P<product_id>[\w-]+)/",
    r"https://www.amazon.com/dp/(?P<product_id>[/w-]+)",
    r"https://www.amazon.com/gp/product/(?P<product_id>[/w-]+)"
]

# 3
def extract_product_id_from_url(url):
    product_id = None
    for regex_str in regex_options:
        regex = re.compile(regex_str)
        match = regex.match(url)
        if match != None:
            try:
                product_id = match['product_id']
            except:
                pass
        return product_id

# %%
# 2
def clean_page_links(page_links=[], category=None):
    final_page_links = []
    for url in page_links:
        product_id = extract_product_id_from_url(url)
        if product_id != None:
            final_page_links.append({"url" :url, "product_id":product_id , "category":category})
    return final_page_links

# %%
def perform_scrape(cleaned_items = []):
    extracted_data = []
#     print(len(cleaned_items))
    for link in cleaned_items:
        url = link["url"]
        product_id = link["product_id"]
        product_title, product_price = None , None
        try:
            product_title, product_price = scrape_product_page(url)
         
        except:
            pass
        
        if product_title != None and product_price != None:
            product_data = {
                "url":url,
                "product_id": product_id ,
                "product_title" : product_title,
                "product_price": product_price
            }
            
            extracted_data.append(product_data)
            
    return extracted_data

# %%
# cleaned_page_links = scrape_category_product_links(categories)
# # print(cleaned_page_links)
# data_extracted = perform_scrape(cleaned_items = cleaned_page_links)
# print(data_extracted)

# %%
# 4
def extract_categories_and_save(categories=[]):
    cleaned_page_links = scrape_category_product_links(categories)
    df = pd.DataFrame(cleaned_page_links)
    df.to_csv(product_category_links_output, index=False)

# %%
extract_categories_and_save(categories)

# %%
df = pd.read_csv(product_category_links_output)
df.head(n=50)
# Out:
#                                                   url  product_id  \
# 0   https://www.amazon.com/6102278-Suplemento-base...  B00NHQF65S
# 1   https://www.amazon.com/Little-Tikes-EasyScore-...  B01C5A2WJO
# 2   https://www.amazon.com/Play-Doh-Pack-Case-Blue...  B07BC152DC
# 3   https://www.amazon.com/Baby-Einstein-Creative-...  B083XNLSN3
# 4   https://www.amazon.com/First-Princess-Make-Kit...  B07FPWYY79
# 5   https://www.amazon.com/First-Years-Stack-Up-Cu...  B00005C5H4
# 6   https://www.amazon.com/SplashEZ-Splash-Sprinkl...  B0836WRWFY
# 7   https://www.amazon.com/Intex-River-Lounge-Infl...  B000PEOMC8
# 8   https://www.amazon.com/Crayola-Shark-Coloring-...  B07PMLL5L7
# 9   https://www.amazon.com/Crayola-12-Ultra-Clean-...  B003HGGPLW
# 10  https://www.amazon.com/WOWMAZING-Giant-Bubble-...  B01CK78BLA
# 11  https://www.amazon.com/Mattel-Games-FPD61-Mine...  B074RCV4HQ
# 12  https://www.amazon.com/Child-11-inch-Yoda-like...  B0825SNHP1
# 13  https://www.amazon.com/Hasbro-A5640-Connect-4-...  B00D8STBHY
# 14  https://www.amazon.com/Tara-Toys-Barbie-Neckla...  B07WWZBF5G
# 15  https://www.amazon.com/Gazillion-Bubbles-1-Lit...  B001LO9TS8
# 16  https://www.amazon.com/Kinetic-Sand-Sandtastic...  B07M5TPM8Q
# 17  https://www.amazon.com/Crayola-Twistables-Clas...  B00062J99K
# 18  https://www.amazon.com/LeapFrog-Scoop-Learn-Cr...  B06XKXPLRP
# 19  https://www.amazon.com/ArtCreativity-Bubble-La...  B07RJYZHN1
# 20  https://www.amazon.com/Inflatable-Splash-Sprin...  B082WXCM5W
# 21  https://www.amazon.com/Talkies-Channels-Backli...  B085Y6TS3S
# 22  https://www.amazon.com/L-L-Surprise-Surprises-...  B07XSPCBVP
# 23  https://www.amazon.com/Flybar-Jumper-Toddlers-...  B00WTDXSDM
# 24  https://www.amazon.com/CozyBomB-Magnetic-Fishi...  B07B6NP36Q
# 25  https://www.amazon.com/Sable-Inflatable-Kiddie...  B082X1JWXC
# 26  https://www.amazon.com/Waterproof-Stickers-Lug...  B07QR3NWGK
# 27  https://www.amazon.com/First-Years-Disney-Mick...  B06Y1G2MH9
# 28  https://www.amazon.com/VTech-Sit-to-Stand-Lear...  B07CRSXMW8
# 29  https://www.amazon.com/Creativity-Kids-Glow-Da...  B07SXLYQ6S
# 30  https://www.amazon.com/SwimWays-Spring-Activit...  B000WQZD9U
# 31  https://www.amazon.com/Exploding-Kittens-LLC-E...  B010TQY7A8
# 32  https://www.amazon.com/Cards-Against-Humanity-...  B004S8F7QM
# 33  https://www.amazon.com/Fisher-Price-Rattle-Roc...  B071FLSWBS
# 34  https://www.amazon.com/SwimWays-Toypedo-Bandit...  B0038ZVPFI
# 35  https://www.amazon.com/Fix-Find-flexible-color...  B004UHED0C
# 36  https://www.amazon.com/Click-Play-Phthalate-Cr...  B00PYLU3GG
# 37  https://www.amazon.com/Bunch-Balloons-Rapid-Fi...  B07XYQY7SV
# 38  https://www.amazon.com/Animal-Suncatcher-Refil...  B07KD24XBS
# 39  https://www.amazon.com/SunWorks-Construction-P...  B002LARR7Q
# 40  https://www.amazon.com/Disney-Pixar-Story-Alie...  B07HD27YZT
# 41  https://www.amazon.com/Step2-Duck-Dive-Water-T...  B07BFQDHH4
# 42  https://www.amazon.com/Double-Inflatables-Matt...  B084Y86V3J
# 43  https://www.amazon.com/Intex-Float-Inflatable-...  B000OV0X4S
# 44  https://www.amazon.com/Mattel-Games-Official-A...  B07P6MZPK3
# 45  https://www.amazon.com/Munchkin-17040-Fishin-B...  B01N52DUNK
# 46  https://www.amazon.com/Pacon-PAC6555-Lightweig...  B0013CDJTS
# 47  https://www.amazon.com/Jasonwell-Sprinkle-Spri...  B07LG9CGF1
# 48  https://www.amazon.com/Aqua-Multi-Purpose-Infl...  B01N7FHWPY
# 49  https://www.amazon.com/Rockerz-450-Wireless-Bl...  B07PR1CL3S
#
#                                              category
# 0   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 1   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 2   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 3   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 4   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 5   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 6   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 7   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 8   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 9   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 10  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 11  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 12  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 13  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 14  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 15  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 16  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 17  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 18  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 19  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 20  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 21  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 22  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 23  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 24  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 25  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 26  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 27  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 28  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 29  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 30  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 31  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 32  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 33  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 34  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 35  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 36  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 37  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 38  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 39  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 40  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 41  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 42  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 43  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 44  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 45  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 46  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 47  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 48  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 49  {'url': 'https://www.amazon.in/gp/bestsellers/...

# %%
df.shape # to get rows and columns in dataframe
# Out:
# (147, 3)

# %%
df_sub = df.copy() #to copy dataframe
# df_sub = df.head(n=10)

# %%
def row_scrape_event(row):
    link = row['url']
    scraped = 0
    try:
        scraped = row['scraped']
    except:
        pass
    if scraped == 1 or scraped =="1":
        return row
    product_id = row['product_id']
    title, price = (None, None)
    try:
        title,price = scrape_product_page(link)
    except:
        pass
    
    row['title'] = title
    row['price'] = price
    row['scraped'] = 1
    row['timestamp'] = datetime.datetime.now().timestamp()
#     print(title, price)
    return row

# %%
df_sub = df_sub.apply(row_scrape_event , axis=1)
df_sub.head(n=60)
# Out:
#                                                   url  product_id  \
# 0   https://www.amazon.com/6102278-Suplemento-base...  B00NHQF65S
# 1   https://www.amazon.com/Little-Tikes-EasyScore-...  B01C5A2WJO
# 2   https://www.amazon.com/Play-Doh-Pack-Case-Blue...  B07BC152DC
# 3   https://www.amazon.com/Baby-Einstein-Creative-...  B083XNLSN3
# 4   https://www.amazon.com/First-Princess-Make-Kit...  B07FPWYY79
# 5   https://www.amazon.com/First-Years-Stack-Up-Cu...  B00005C5H4
# 6   https://www.amazon.com/SplashEZ-Splash-Sprinkl...  B0836WRWFY
# 7   https://www.amazon.com/Intex-River-Lounge-Infl...  B000PEOMC8
# 8   https://www.amazon.com/Crayola-Shark-Coloring-...  B07PMLL5L7
# 9   https://www.amazon.com/Crayola-12-Ultra-Clean-...  B003HGGPLW
# 10  https://www.amazon.com/WOWMAZING-Giant-Bubble-...  B01CK78BLA
# 11  https://www.amazon.com/Mattel-Games-FPD61-Mine...  B074RCV4HQ
# 12  https://www.amazon.com/Child-11-inch-Yoda-like...  B0825SNHP1
# 13  https://www.amazon.com/Hasbro-A5640-Connect-4-...  B00D8STBHY
# 14  https://www.amazon.com/Tara-Toys-Barbie-Neckla...  B07WWZBF5G
# 15  https://www.amazon.com/Gazillion-Bubbles-1-Lit...  B001LO9TS8
# 16  https://www.amazon.com/Kinetic-Sand-Sandtastic...  B07M5TPM8Q
# 17  https://www.amazon.com/Crayola-Twistables-Clas...  B00062J99K
# 18  https://www.amazon.com/LeapFrog-Scoop-Learn-Cr...  B06XKXPLRP
# 19  https://www.amazon.com/ArtCreativity-Bubble-La...  B07RJYZHN1
# 20  https://www.amazon.com/Inflatable-Splash-Sprin...  B082WXCM5W
# 21  https://www.amazon.com/Talkies-Channels-Backli...  B085Y6TS3S
# 22  https://www.amazon.com/L-L-Surprise-Surprises-...  B07XSPCBVP
# 23  https://www.amazon.com/Flybar-Jumper-Toddlers-...  B00WTDXSDM
# 24  https://www.amazon.com/CozyBomB-Magnetic-Fishi...  B07B6NP36Q
# 25  https://www.amazon.com/Sable-Inflatable-Kiddie...  B082X1JWXC
# 26  https://www.amazon.com/Waterproof-Stickers-Lug...  B07QR3NWGK
# 27  https://www.amazon.com/First-Years-Disney-Mick...  B06Y1G2MH9
# 28  https://www.amazon.com/VTech-Sit-to-Stand-Lear...  B07CRSXMW8
# 29  https://www.amazon.com/Creativity-Kids-Glow-Da...  B07SXLYQ6S
# 30  https://www.amazon.com/SwimWays-Spring-Activit...  B000WQZD9U
# 31  https://www.amazon.com/Exploding-Kittens-LLC-E...  B010TQY7A8
# 32  https://www.amazon.com/Cards-Against-Humanity-...  B004S8F7QM
# 33  https://www.amazon.com/Fisher-Price-Rattle-Roc...  B071FLSWBS
# 34  https://www.amazon.com/SwimWays-Toypedo-Bandit...  B0038ZVPFI
# 35  https://www.amazon.com/Fix-Find-flexible-color...  B004UHED0C
# 36  https://www.amazon.com/Click-Play-Phthalate-Cr...  B00PYLU3GG
# 37  https://www.amazon.com/Bunch-Balloons-Rapid-Fi...  B07XYQY7SV
# 38  https://www.amazon.com/Animal-Suncatcher-Refil...  B07KD24XBS
# 39  https://www.amazon.com/SunWorks-Construction-P...  B002LARR7Q
# 40  https://www.amazon.com/Disney-Pixar-Story-Alie...  B07HD27YZT
# 41  https://www.amazon.com/Step2-Duck-Dive-Water-T...  B07BFQDHH4
# 42  https://www.amazon.com/Double-Inflatables-Matt...  B084Y86V3J
# 43  https://www.amazon.com/Intex-Float-Inflatable-...  B000OV0X4S
# 44  https://www.amazon.com/Mattel-Games-Official-A...  B07P6MZPK3
# 45  https://www.amazon.com/Munchkin-17040-Fishin-B...  B01N52DUNK
# 46  https://www.amazon.com/Pacon-PAC6555-Lightweig...  B0013CDJTS
# 47  https://www.amazon.com/Jasonwell-Sprinkle-Spri...  B07LG9CGF1
# 48  https://www.amazon.com/Aqua-Multi-Purpose-Infl...  B01N7FHWPY
# 49  https://www.amazon.com/Rockerz-450-Wireless-Bl...  B07PR1CL3S
# 50  https://www.amazon.com/Mi-20000mAH-Li-Polymer-...  B07VXJS7DH
# 51  https://www.amazon.com/Redmi-Note-Cosmic-Purpl...  B07X2KLKRT
# 52  https://www.amazon.com/Mi-Earphones-Basic-Mic-...  B07CD2BN46
# 53  https://www.amazon.com/255-Bluetooth-Wireless-...  B07C2VJXP4
# 54  https://www.amazon.com/Fluorite-Purple-Storage...  B07PTLD8P9
# 55  https://www.amazon.com/HP-X1000-Wired-Mouse-Bl...  B009VCGPSY
# 56  https://www.amazon.com/Test-Exclusive-669/dp/B...  B07HGH8ML7
# 57  https://www.amazon.com/BassHeads-152-Secure-Br...  B07KY2KP8M
# 58  https://www.amazon.com/Redmi-Note-Pro-Storage-...  B07X4PKGSN
# 59  https://www.amazon.com/boAt-BassHeads-100-Head...  B07234XXJF
#
#                                              category  \
# 0   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 1   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 2   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 3   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 4   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 5   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 6   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 7   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 8   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 9   {'url': 'https://www.amazon.com/Best-Sellers-T...
# 10  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 11  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 12  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 13  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 14  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 15  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 16  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 17  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 18  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 19  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 20  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 21  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 22  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 23  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 24  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 25  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 26  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 27  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 28  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 29  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 30  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 31  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 32  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 33  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 34  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 35  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 36  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 37  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 38  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 39  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 40  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 41  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 42  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 43  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 44  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 45  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 46  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 47  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 48  {'url': 'https://www.amazon.com/Best-Sellers-T...
# 49  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 50  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 51  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 52  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 53  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 54  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 55  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 56  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 57  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 58  {'url': 'https://www.amazon.in/gp/bestsellers/...
# 59  {'url': 'https://www.amazon.in/gp/bestsellers/...
#
#                                                 title   price  scraped  \
# 0                                                None    None        1
# 1                                                None    None        1
# 2                                                None    None        1
# 3                                                None    None        1
# 4                                                None    None        1
# 5                                                None    None        1
# 6                                                None    None        1
# 7                                                None    None        1
# 8                                                None    None        1
# 9                                                None    None        1
# 10                                               None    None        1
# 11                                               None    None        1
# 12                                               None    None        1
# 13                                               None    None        1
# 14                                               None    None        1
# 15                                               None    None        1
# 16                                               None    None        1
# 17                                               None    None        1
# 18                                               None    None        1
# 19                                               None    None        1
# 20                                               None    None        1
# 21                                               None    None        1
# 22                                               None    None        1
# 23                                               None    None        1
# 24                                               None    None        1
# 25                                               None    None        1
# 26                                               None    None        1
# 27  The First Years Disney Baby Bathtime Squirt To...   $7.99        1
# 28                                               None    None        1
# 29                                               None    None        1
# 30                                               None    None        1
# 31                                               None    None        1
# 32                                               None    None        1
# 33  Fisher-Price Rattle 'n Rock Maracas, Blue/Oran...   $6.99        1
# 34                                               None    None        1
# 35  Fix Find 52 Inch Colorful Foam Pool Swim Noodl...  $13.29        1
# 36                                               None    None        1
# 37                                               None    None        1
# 38                                               None    None        1
# 39                                               None    None        1
# 40                                               None    None        1
# 41                                               None    None        1
# 42                                               None    None        1
# 43                                               None    None        1
# 44                                               None    None        1
# 45                          Munchkin Fishin' Bath Toy   $7.73        1
# 46                                               None    None        1
# 47                                               None    None        1
# 48                                               None    None        1
# 49                                               None    None        1
# 50                                               None    None        1
# 51                                               None    None        1
# 52                                               None    None        1
# 53                                               None    None        1
# 54                                               None    None        1
# 55                                               None    None        1
# 56                                               None    None        1
# 57                                               None    None        1
# 58                                               None    None        1
# 59                                               None    None        1
#
#        timestamp
# 0   1.591820e+09
# 1   1.591820e+09
# 2   1.591820e+09
# 3   1.591820e+09
# 4   1.591820e+09
# 5   1.591820e+09
# 6   1.591820e+09
# 7   1.591820e+09
# 8   1.591820e+09
# 9   1.591820e+09
# 10  1.591820e+09
# 11  1.591820e+09
# 12  1.591820e+09
# 13  1.591820e+09
# 14  1.591820e+09
# 15  1.591820e+09
# 16  1.591820e+09
# 17  1.591820e+09
# 18  1.591820e+09
# 19  1.591820e+09
# 20  1.591820e+09
# 21  1.591820e+09
# 22  1.591820e+09
# 23  1.591820e+09
# 24  1.591820e+09
# 25  1.591820e+09
# 26  1.591820e+09
# 27  1.591820e+09
# 28  1.591820e+09
# 29  1.591820e+09
# 30  1.591820e+09
# 31  1.591820e+09
# 32  1.591820e+09
# 33  1.591820e+09
# 34  1.591820e+09
# 35  1.591820e+09
# 36  1.591820e+09
# 37  1.591820e+09
# 38  1.591820e+09
# 39  1.591820e+09
# 40  1.591820e+09
# 41  1.591820e+09
# 42  1.591820e+09
# 43  1.591820e+09
# 44  1.591820e+09
# 45  1.591820e+09
# 46  1.591820e+09
# 47  1.591820e+09
# 48  1.591820e+09
# 49  1.591820e+09
# 50  1.591820e+09
# 51  1.591820e+09
# 52  1.591820e+09
# 53  1.591820e+09
# 54  1.591820e+09
# 55  1.591820e+09
# 56  1.591820e+09
# 57  1.591820e+09
# 58  1.591820e+09
# 59  1.591820e+09

# %%
final_df = pd.concat([df, df_sub])
final_df.to_csv(products_output, index=False)
final_df.head()
# Out:
#                                                  url  product_id  \
# 0  https://www.amazon.com/6102278-Suplemento-base...  B00NHQF65S
# 1  https://www.amazon.com/Little-Tikes-EasyScore-...  B01C5A2WJO
# 2  https://www.amazon.com/Play-Doh-Pack-Case-Blue...  B07BC152DC
# 3  https://www.amazon.com/Baby-Einstein-Creative-...  B083XNLSN3
# 4  https://www.amazon.com/First-Princess-Make-Kit...  B07FPWYY79
#
#                                             category title price  scraped  \
# 0  {'url': 'https://www.amazon.com/Best-Sellers-T...   NaN   NaN      NaN
# 1  {'url': 'https://www.amazon.com/Best-Sellers-T...   NaN   NaN      NaN
# 2  {'url': 'https://www.amazon.com/Best-Sellers-T...   NaN   NaN      NaN
# 3  {'url': 'https://www.amazon.com/Best-Sellers-T...   NaN   NaN      NaN
# 4  {'url': 'https://www.amazon.com/Best-Sellers-T...   NaN   NaN      NaN
#
#    timestamp
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
