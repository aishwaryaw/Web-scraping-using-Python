# %%
import os
from requests_html import HTML
import requests
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome(options= options) # so that browser does not get open everytime we run the code.

# %%
categories = [
    "https://www.amazon.com/Best-Sellers-Toys-Games/zgbs/toys-and-games/",
    "https://www.amazon.in/gp/bestsellers/electronics/ref=zg_bs_nav_0",
    "https://www.amazon.in/gp/bestsellers/garden/ref=zg_bs_nav_0"
]

# %%
first_url = categories[0]
driver.get(first_url)
body_el = driver.find_element_by_css_selector("body")
html_str = body_el.get_attribute("innerHTML")
# print(html_str)
html_obj = HTML(html = html_str)
# print(html_obj)

# %%
new_links = [x for x in html_obj.links if x.startswith("/")]
new_links = [x for x in new_links if "product-reviews" not in x]
# print(new_links)

# %%
page_links = [f"https://www.amazon.com{x}" for x in new_links]
page_links
# Out:
# ['https://www.amazon.com/gp/registry/wishlist?triggerElementID=createList&ref_=nav_ListFlyout_create',
#  'https://www.amazon.com/Fix-Find-flexible-colorful-Noodles/dp/B004UHED0C/ref=zg_bs_toys-and-games_29/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/showroom?ref_=nav_ListFlyout_srm_your_desk_wl',
#  'https://www.amazon.com/gp/subs/primeclub/account/homepage.html?ref_=nav_AccountFlyout_prime',
#  'https://www.amazon.com/gp/help/customer/display.html?ie=UTF8&nodeId=508510&ref_=footer_gw_m_b_he',
#  'https://www.amazon.com/gp/browse.html?node=11261610011&ref_=nav_AccountFlyout_b2b_reg',
#  'https://www.amazon.com/ideas/saves?ref_=nav_ListFlyout_strm_in_youtique_lists',
#  'https://www.amazon.com/Flybar-Jumper-Toddlers-Durable-Supports/dp/B00WTDXSDM/ref=zg_bs_toys-and-games_19/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/browse.html?node=17235386011&ref_=nav_cs_whole_foods',
#  'https://www.amazon.com/gp/help/customer/display.html?ie=UTF8&nodeId=468520&ref_=footer_shiprates',
#  'https://www.amazon.com/clouddrive?ref_=nav_AccountFlyout_clddrv',
#  'https://www.amazon.com/gp/clpf?ref_=nav_ListFlyout_smi_se_ya_lll_ll',
#  'https://www.amazon.com/b/?_encoding=UTF8&ld=AZUSSOA-sell&node=12766669011&ref_=nav_cs_sell',
#  'https://www.amazon.com/toys/b/?ie=UTF8&node=165793011&ref_=sv_t_2',
#  'https://www.amazon.com/gp/bestsellers/toys-and-games/?ie=UTF8&ie=UTF8&ref_=sv_t_3',
#  'https://www.amazon.com/gp/yourstore/pym/ref=pd_pyml_rhf/138-2116477-9040019',
#  'https://www.amazon.com/Pacon-PAC6555-Lightweight-Construction-Assorted/dp/B0013CDJTS/ref=zg_bs_toys-and-games_27/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/First-Princess-Make-Kit-Everything/dp/B07FPWYY79/ref=zg_bs_toys-and-games_18/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gcx/Summer-toy-list-preview/gfhz/events/?_encoding=UTF8&categoryId=kgg-stl-preview&ref_=sv_t_1',
#  'https://www.amazon.com/Coupons/b/?_encoding=UTF8&node=2231352011&ref_=nav_cs_coupons',
#  'https://www.amazon.com/Sassy-Developmental-Months-Patterns-Developing/dp/B004AHMCMI/ref=zg_bs_toys-and-games_48/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/mas/your-account/myapps?ref_=nav_AccountFlyout_aad',
#  'https://www.amazon.com/gift-cards/b/?ie=UTF8&node=2238192011&ref_=nav_cs_gc',
#  'https://www.amazon.com/yourmembershipsandsubscriptions?ref_=nav_AccountFlyout_digital_subscriptions',
#  'https://www.amazon.com/Waterproof-Stickers-Luggage-Scrapbook-Postcard/dp/B07QR3NWGK/ref=zg_bs_toys-and-games_23/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/help/customer/display.html?nodeId=508510&ref_=nav_cs_customerservice',
#  'https://www.amazon.com/gp/css/order-history?ie=UTF8&ref_=footer_yo',
#  'https://www.amazon.com/SplashEZ-Splash-Sprinkler-Toddler-Learning/dp/B0836WRWFY/ref=zg_bs_toys-and-games_4/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/alm/storefront?_encoding=UTF8&almBrandId=QW1hem9uIEZyZXNo&ref_=footer_aff_fresh',
#  'https://www.amazon.com/Homech-Inflatable-Swimming-Full-Sized-Toddlers/dp/B083PRCZDM/ref=zg_bs_toys-and-games_37/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/seller-account/mm-summary-page.html?ie=UTF8&ld=AZFooterSelfPublish&ref_=footer_publishing&topic=200260520',
#  'https://www.amazon.com/Intex-River-Lounge-Inflatable-Diameter/dp/B000PEOMC8/ref=zg_bs_toys-and-games_3/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/finds?ref_=nav_cs_foundit',
#  'https://www.amazon.com/gp/help/customer/accessibility',
#  'https://www.amazon.com/gp/BIT?bitCampaignCode=a0032&ref_=nav_ListFlyout_bit_v2_a0032',
#  'https://www.amazon.com/Mattel-Games-Official-Amazon-Exclusive/dp/B07P6MZPK3/ref=zg_bs_toys-and-games_13/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/stylequiz/?ref_=nav_ListFlyout_sq_ya_yl',
#  'https://www.amazon.com/L-L-Surprise-Surprises-Including/dp/B07XSPCBVP/ref=zg_bs_toys-and-games_10/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/Little-Tikes-EasyScore-Basketball-Exclusive/dp/B01C5A2WJO/ref=zg_bs_toys-and-games_35/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/registry/search?ref_=nav_ListFlyout_find',
#  'https://www.amazon.com/gp/navigation-country/select-country/ref=footer_icp_cp_t1?ie=UTF8&preferencesReturnUrl=%2FBest-Sellers-Toys-Games%2Fzgbs%2Ftoys-and-games%2F',
#  'https://www.amazon.com/ref=footer_logo',
#  'https://www.amazon.com/Disney-Pixar-Story-Aliens-Figure/dp/B07HD27YZT/ref=zg_bs_toys-and-games_40/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/First-Years-Stack-Up-Cups/dp/B00005C5H4/ref=zg_bs_toys-and-games_8/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/baby-reg/homepage?ref_=nav_ListFlyout_br',
#  'https://www.amazon.com/Exploding-Kittens-LLC-EKG-ORG1-1-Card/dp/B010TQY7A8/ref=zg_bs_toys-and-games_36/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/Aqua-Multi-Purpose-Inflatable-Removable-Resistant/dp/B01N7FHWPY/ref=zg_bs_toys-and-games_1/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/new-releases/?ref_=nav_cs_newreleases',
#  'https://www.amazon.com/gp/subscribe-and-save/manager/viewsubscriptions?ref_=nav_AccountFlyout_sns',
#  'https://www.amazon.com/ideas?ref_=nav_ListFlyout_idea_nav',
#  'https://www.amazon.com/b/?_encoding=UTF8&ld=AZUSSOA-seemore&node=18190131011&ref_=footer_seemore',
#  'https://www.amazon.com/interestbasedads/ref=footer_iba',
#  'https://www.amazon.com/Mattel-Games-FPD61-Minecraft-Card/dp/B074RCV4HQ/ref=zg_bs_toys-and-games_30/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/css/order-history?ref_=nav_orders_first',
#  'https://www.amazon.com/First-Years-Disney-Mickey-Squirt/dp/B06Y1G2MH9/ref=zg_bs_toys-and-games_38/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/
138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/Prime-Instant-Video/s/browse?node=2676882011&ref_=nav_AccountFlyout_piv',
#  'https://www.amazon.com/iss/credit/rewardscardmember?_encoding=UTF8&plattr=CBFOOT&ref_=footer_cbcc',
#  'https://www.amazon.com/b/?ie=UTF8&node=17728536011&ref_=sv_t_6',
#  'https://www.amazon.com/discover/?ref_=nav_ListFlyout_sbl',
#  'https://www.amazon.com/b/?node=16548547011&ref_=nav_cs_freeshipping',
#  'https://www.amazon.com/Currency-Converter/b?ie=UTF8&node=388305011&ref_=footer_tfx',
#  'https://www.amazon.com/business?_encoding=UTF8&ref_=footer_retail_b2b',
#  'https://www.amazon.com/dp/B07CBJQS16?_encoding=UTF8&ie=UTF-8&place=camp&plattr=CCLFOOT&pr=ibprox&ref_=footer_ccl',
#  'https://www.amazon.com/gp/BIT/ref=footer_bit_v2_us_A0029?bitCampaignCode=A0029',
#  'https://www.amazon.com/ref=nav_logo',
#  'https://www.amazon.com/gp/css/order-history?ref_=nav_AccountFlyout_orders',
#  'https://www.amazon.com/gp/help/customer/display.html?ie=UTF8&nodeId=GDFU3JS5AL6SYHRD&ref_=footer_covid',
#  'https://www.amazon.com/Best-Sellers-Toys-Games/zgbs/toys-and-games/uedata/nvp/unsticky/138-2116477-9040019/zeitgeist/ntpoffrw?tepes=1&id=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/hz/mycd/myx?ref_=nav_AccountFlyout_myk',
#  'https://www.amazon.com/Manhattan-Toy-Winkel-Sensory-Teether/dp/B000BNCA4K/ref=zg_bs_toys-and-games_46/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/prime?ref_=nav_logo_prime_join',
#  'https://www.amazon.com/amazon-devices/b?ie=UTF8&node=2102313011&ref_=footer_devices',
#  'https://www.amazon.com/gp/css/homepage.html?ref_=nav_AccountFlyout_ya',
#  'https://www.amazon.com/gp/video/library?ref_=nav_AccountFlyout_yvl',
#  'https://www.amazon.com/toys/b/?ie=UTF8&node=165793011&ref_=sv_t_4',
#  'https://www.amazon.com/prime?ref_=nav_prime_try_btn',
#  'https://www.amazon.com/compare-credit-card-offers/b?ie=UTF8&node=3561432011&ref_=footer_ccmp',
#  'https://www.amazon.com/yourpets?ref_=nav_AccountFlyout_pet_profiles',
#  'https://www.amazon.com/b?ie=UTF8&node=16218619011&ref_=footer_swp',
#  'https://www.amazon.com/Inflatable-Splash-Sprinkler-Toddlers-Outdoor/dp/B082WXCM5W/ref=zg_bs_toys-and-games_5/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/b?ie=UTF8&node=14498690011&ref_=amzn_nav_ftr_swa',
#  'https://www.amazon.com/gp/help/customer/display.html?ie=UTF8&nodeId=468496&ref_=footer_privacy',
#  'https://www.amazon.com/gp/css/homepage.html?ie=UTF8&ref_=footer_ya',
#  'https://www.amazon.com/gp/cart/view.html?ref_=nav_cart',
#  'https://www.amazon.com/gp/navigation/redirector.html/ref=sign-in-redirect?ie=UTF8&associationHandle=usflex&currentPageURL=https%3A%2F%2Fwww.amazon.com%2FBest-Sellers-Toys-Games%2Fzgbs%2Ftoys-and-games%2F%3Fref_%3Dnav_custrec_signin&pageType=zeitgeist&switchAccount=&yshURL=https%3A%2F%2Fwww.amazon.com%2Fgp%2Fyourstore%2Fhome%3Fie%3DUTF8%26ref_%3Dnav_custrec_signin',
#  'https://www.amazon.com/Kinetic-Sand-Sandtastic-Playset-Tools/dp/B07M5TPM8Q/ref=zg_bs_toys-and-games_42/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp
138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/wedding/home?ref_=nav_ListFlyout_wr',
#  'https://www.amazon.com/b/?node=12766669011&ld=AZUSSOA-yaflyout&ref_=nav_cs_sell',
#  'https://www.amazon.com/gp/kindle/ku/ku_central?ref_=nav_AccountFlyout_ku',
#  'https://www.amazon.com/Crayola-Shark-Coloring-Pages-Wonder/dp/B07PMLL5L7/ref=zg_bs_toys-and-games_15/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/stores/node/2528919011/?field-lbr_brands_browse-bin=AmazonBasics&ref_=nav_cs_amazonbasics',
#  'https://www.amazon.com/gp/customer-preferences/select-language/ref=footer_lang_t1?ie=UTF8&preferencesReturnUrl=%2FBest-Sellers-Toys-Games%2Fzgbs%2Ftoys-and-games%2F',
#  'https://www.amazon.com/gp/bestsellers/?ref_=nav_cs_bestsellers',
#  'https://www.amazon.com/Munchkin-17040-Fishin-Bath-Toy/dp/B01N52DUNK/ref=zg_bs_toys-and-games_34/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/Reload-Your-Gift-Card-Balance/b?ie=UTF8&node=10232440011&ref_=footer_reload_us',
#  'https://www.amazon.com/Fisher-Price-Rattle-Rock-Maracas-Orange/dp/B071FLSWBS/ref=zg_bs_toys-and-games_43/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/PRINCESSEA-Outdoor-Mermaid-Childrens-Sprinkler/dp/B083V663ZJ/ref=zg_bs_toys-and-games_45/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F',
#  'https://www.amazon.com/gp/yourstore?ref_=nav_AccountFlyout_recs',
#  'https://www.amazon.com/hz/mycd/myx?_encoding=UTF8&ref_=footer_myk',
#  'https://www.amazon.com/STRING-subnav-prime-photos/b?ie=UTF8&node=13234696011&ref_=gno_p_foot',
#  'https://www.amazon.com/Tara-Toys-Barbie-Necklace-Activity/dp/B07WWZBF5G/ref=zg_bs_toys-and-games_6/138-2116477-9040019?_encoding=UTF8&psc=1&refRID=FE9C693VM8KZ37VSYJ7F']

# %%
def scrape_product_page(url, title_lookup="#productTitle", price_lookup="#priceblock_ourprice"):
    driver.get(url)
    print(url)
    time.sleep(1.5)
    body_el = driver.find_element_by_css_selector("body")
    html_str = body_el.get_attribute("innerHTML")
    html_obj = HTML(html = html_str)
    title = html_obj.find(title_lookup, first=True).text # first= True as find returns a list of elements
    price = html_obj.find(price_lookup, first=True).text
    return title, price

# title , price = scrape_product_page("https://www.amazon.in/Samsung-Galaxy-Space-Black-Storage/dp/B07HGN617M/ref=zg_bs_electronics_2?_encoding=UTF8&psc=1&refRID=H64JPJV0KPKTTPF3MGGP")
# print(title, price)

for link in page_links:
    product_price , product_title = None , None
    try:
        product_price , product_title = scrape_product_page(link)
    except:
        pass
    if product_title != None and product_price != None:
        print(link, product_title,product_price)
# Out:
# https://www.amazon.in/Samsung-Galaxy-Space-Black-Storage/dp/B07HGN617M/ref=zg_bs_electronics_2?_encoding=UTF8&psc=1&refRID=H64JPJV0KPKTTPF3MGGP
# Samsung Galaxy M31 (Space Black, 6GB RAM, 128GB Storage) ₹ 16,999.00

# %%
# https://www.amazon.com/Cartulina-SunWorks-de-Pacon-Negro/dp/B002LARR7Q/ref=zg_bs_toys-and-games_47/145-2143239-3431858?_encoding=UTF8&psc=1&refRID=74QVQYR37NW6EC5D1Z2X
# actual url is - https://www.amazon.com/Cartulina-SunWorks-de-Pacon-Negro/dp/B002LARR7Q
# base_url/<slug>/dp/<product_id>
